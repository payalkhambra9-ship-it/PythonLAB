# %% [markdown]
#  ### File handling

# %%
#open("file_name","mode")
#model :::=
#r
#w
#a
#x

# %% [markdown]
#   ## read

# %%
file=open("liet.txt",'r')
file.read()
# Out:
# 'Life is a journey of small steps, where every experience teaches us something new ðŸ™‚. Even challenges help us grow stronger and wiser if we face them with patience. By believing in ourselves and staying positive, we can slowly turn our dreams into reality ðŸ™‚.Every day brings a new chance to learn and improve ðŸ™‚. When we stay hopeful and keep trying, even simple efforts can lead to big changes ðŸ˜Š.\n\nSuccess does not come overnight ðŸ™‚. It is built through hard work, consistency, and believing in yourself even when things feel difficult ðŸ˜”.\n\nKind words and small actions can make a big difference in someoneâ€™s life ðŸ™‚. Being kind costs nothing but creates happiness for everyone ðŸ˜Š.\n\nMistakes are not failures ðŸ™‚. They are lessons that guide us toward doing better next time ðŸ˜Œ.'

# %%
file=open("liet.txt",'r')
file.read()
file.close()

# %%
file=open("liet.txt",'r')
file.readline(2)
# Out:
# 'Li'

# %%
open("liet.txt").read()
# Out:
# 'Life is a journey of small steps, where every experience teaches us something new ðŸ™‚. Even challenges help us grow stronger and wiser if we face them with patience. By believing in ourselves and staying positive, we can slowly turn our dreams into reality ðŸ™‚.Every day brings a new chance to learn and improve ðŸ™‚. When we stay hopeful and keep trying, even simple efforts can lead to big changes ðŸ˜Š.\n\nSuccess does not come overnight ðŸ™‚. It is built through hard work, consistency, and believing in yourself even when things feel difficult ðŸ˜”.\n\nKind words and small actions can make a big difference in someoneâ€™s life ðŸ™‚. Being kind costs nothing but creates happiness for everyone ðŸ˜Š.\n\nMistakes are not failures ðŸ™‚. They are lessons that guide us toward doing better next time ðŸ˜Œ.'

# %%
with open("liet.txt",'r') as file:
    print(file.read())
# Out:
# Life is a journey of small steps, where every experience teaches us something new ðŸ™‚. Even challenges help us grow stronger and wiser if we face them with patience. By believing in ourselves and staying positive, we can slowly turn our dreams into reality ðŸ™‚.Every day brings a new chance to learn and improve ðŸ™‚. When we stay hopeful and keep trying, even simple efforts can lead to big changes ðŸ˜Š.
#
# Success does not come overnight ðŸ™‚. It is built through hard work, consistency, and believing in yourself even when things feel difficult ðŸ˜”.
#
# Kind words and small actions can make a big difference in someoneâ€™s life ðŸ™‚. Being kind costs nothing but creates happiness for everyone ðŸ˜Š.
#
# Mistakes are not failures ðŸ™‚. They are lessons that guide us toward doing better next time ðŸ˜Œ.

# %% [markdown]
# ### Write mode

# %%
file=open("liet.txt",'w')
file.write("Hello world")
file.close()

# %%
open("liet.txt",'r').readlines()
# Out:
# ['Hello world']

# %%
o

# %%
file=open("liet.txt",'w')
file.write("Hello my name is payal")
# Out:
# 22

# %%
file=open("liet.txt",'r')
file.read()
# Out:
# 'Hello my name is payal'

# %%
file=open("liet.txt",'w')
file.write("Hello my name is payal")
# Out:
# 22

# %% [markdown]
# ### append mode

# %%
open("liet,txt",'a')
file.write(" I am a student ofliet college")
file.close()

# %%
file=open("payal.txt",'a')
file.write(" I am a student ofliet college")
file.close()

# %%
file=open('liet.txt','x')
file.read()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 file=open('liet.txt','x')
#       2 file.read()
#
# File c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'liet.txt'

# %%
file=open("liet2.txt",'x')
file.write("Hello my name is payal")
file.close()
