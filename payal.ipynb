# %%
class Student1:
    def doc(self):
        for i in range(1, 4):
            for j in range(1, 3):
                print("i =", i, "j =", j)

st = Student1()
st.doc()
# Out:
# i = 1 j = 1
# i = 1 j = 2
# i = 2 j = 1
# i = 2 j = 2
# i = 3 j = 1
# i = 3 j = 2
